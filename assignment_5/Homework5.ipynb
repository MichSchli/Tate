# %% [markdown]
# Homework 5
# ====
#
# The final homework is designed to let you use everything you have learned up to this point. You should select one of the data sets below and then perform the following three tasks: statistical analysis, building a predictive model, and visualization.
#
# Grading
# ----
# There is no fixed form this time, but note that you need to fulfill all of the parts. Please also add a few lines at the beginning of your code to describe what you did and why. The homework is worth 100pts, you need at least 50 to have it counted.
#
#
# Coöperation
# ----
# You may opt to work together with up to ***2*** other students. In that case, please enter the names of all authors in the code. The group only needs to submit one homework.
# However, group homeworks need to be more substantial in size and depth than individual homeworks.
#
# Data Sets
# ----
# Select one of the following data sets. You are allowed to use as many additional data sets as you would like, but please make sure to document them.
#
# #### Tate Gallery Art Collection
#
# Meta-data on more than 70,000 artworks owned by the London gallery. Biographical information on some artists are provided as well. Files are in CSV and JSON format, and may be downloaded from the data set's [github repository](https://github.com/tategallery/collection).
#
# #### Million Song Dataset
#
# This dataset collects various aspects of one million songs, including meta-data about artists and charateristics of the audio.  It has also been linked up with lyrics through the musiXmatch dataset.
#
# The dataset itself is huge (280 GB), so we suggest you only work with the meta-data and lyrics parts.
#
#
# * (Main page for dataset)[http://labrosa.ee.columbia.edu/millionsong/]
# * (Data example)[http://labrosa.ee.columbia.edu/millionsong/pages/example-track-description]
# * (Description of lyrics dataset)[http://labrosa.ee.columbia.edu/millionsong/musixmatch#desc]
#
#
# #### Trustpilot Danish Reviews
#
# A complete record of the reviews posted on the Danish part of the Trustpilot user review homepage. The Danish site has more than 600,000 users, and includes demographic information (age, gender, place of living) about a large proportion of the them.
#
# * [Review and users](https://dl.dropboxusercontent.com/u/1423772/trustpilot_denmark_auto_gender.jsonl)
# * [Company data](https://dl.dropboxusercontent.com/u/1423772/trustpilot_company.jsonl)
#
# The dataset has the following fields for users, reviews and companies:
#
# **User** Name, ID, profile text, location (city and country), gender, year of birth.
#
# **Review** Title, text, rating (1--5), User ID, Company ID, Date and time of review
#
# **Company** Name, categories (e.g., electronics), number of ratings, description, address, location (city and country)
#
# You do NOT need to include these data sets in your submission, but indicate which one you used.

# %%
#Imports:
# %matplotlib inline

import codecs
import json
import pandas as pd
import numpy as np
import collections
import os
import random
import sklearn
import re
from skimage import io, color
from skimage.io import imshow
from sklearn.feature_extraction import DictVectorizer

# %% [markdown]
# Part1: Statistical Analysis (30pts)
# ----
#
# Perform a statistical analysis of the data. Suggested Python module to use here: `pandas`.
#
# Some questions you should consider:
# * How can you best analyze the data?
# * How many instances are there, how are the values distributed?
# * Are there any outliers?
#
# Grading will consider how thorough the description is, and whether it makes sense for the data set.

# %%
#Define a function to read in a JSON-file and return a dictionary:
def JSONload(filepath):
    with codecs.open(filepath, 'r', encoding='utf-8') as jsonfile:
        return json.load(jsonfile)
           
#Test it:
print JSONload('collection/artworks/a/000/a00001-1035.json')
# Out:
# {u'inscription': None, u'classification': u'on paper, unique', u'height': u'419', u'thumbnailUrl': u'http://www.tate.org.uk/art/images/work/A/A00/A00001_8.jpg', u'id': 1035, u'acno': u'A00001', u'contributors': [{u'gender': u'Male', u'mda': u'Blake, Robert', u'birthYear': 1762, u'fc': u'Robert Blake', u'role': u'artist', u'startLetter': u'B', u'date': u'1762\u20131787', u'id': 38, u'displayOrder': 1}], u'title': u'A Figure Bowing before a Seated Old Man with his Arm Outstretched in Benediction. Verso: Indecipherable Sketch', u'width': u'394', u'subjects': {u'children': [{u'children': [{u'children': [{u'id': 1050, u'name': u'arm/arms raised'}, {u'id': 272, u'name': u'kneeling'}, {u'id': 694, u'name': u'sitting'}], u'name': u'actions: postures and motions', u'id': 92}, {u'children': [{u'id': 195, u'name': u'man'}, {u'id': 1134, u'name': u'man, old'}], u'name': u'adults', u'id': 95}], u'name': u'people', u'id': 91}, {u'children': [{u'children': [{u'id': 5734, u'name': u'blessing'}], u'name': u'universal religious imagery', u'id': 5731}], u'name': u'religion and belief', u'id': 132}], u'name': u'subject', u'id': 1}, u'foreignTitle': None, u'units': u'mm', u'dateText': u'date not known', u'contributorCount': 1, u'medium': u'Watercolour, ink, chalk and graphite on paper. Verso: graphite on paper', u'catalogueGroup': {}, u'movementCount': 0, u'dimensions': u'support: 394 x 419 mm', u'thumbnailCopyright': None, u'creditLine': u'Presented by Mrs John Richmond 1922', u'url': u'http://www.tate.org.uk/art/artworks/blake-a-figure-bowing-before-a-seated-old-man-with-his-arm-outstretched-in-benediction-a00001', u'dateRange': None, u'all_artists': u'Robert Blake', u'acquisitionYear': 1922, u'depth': u'', u'groupTitle': None, u'subjectCount': 6}

# %%
#Define a function to flatten a dictionary:
def flatten(d, parent_key=''):
    items = {}
    for k, v in d.items():
        new_key = parent_key + "_"+k if parent_key else k
        
        if type(v) == type({}):
            nk = k+"_"+unicode(v['id'])
            items.update(flatten(v, nk))
        elif type(v) == type([]):
            for elem in v:
                nk = parent_key + '_' + unicode(elem['id'])
                
                items.update(flatten(elem, nk))
        else:
            items[new_key] = unicode(v)
    
    return items
    
#Define a function to turn an art dictionary into a pandas frame:
def getDataframe(dic, to_be_kept, is_artist=''):
    #Memorize a potential artist:
    a = False
    if is_artist:
        for c in dic['contributors']:
            if is_artist in c['fc']:
                a = True
                break
    
    #First, we crop the dictionary:
    to_be_cropped = list(set(dic.keys()) - set(to_be_kept))
    for key in to_be_cropped:
        if key in dic:
            del dic[key]
    
    #We flatten the dictionary:
    flat_dic = flatten(dic)
    
    #Add a potential artist:
    if is_artist:
        flat_dic['is_'+is_artist] = a
        
    #Then, we make a dictionary:
    return pd.DataFrame(flat_dic, index=[0])
    
    
td = getDataframe(JSONload('collection/artworks/a/000/a00001-1035.json'), ['title'], is_artist='Turner')

print td
# Out:
#   is_Turner                                              title
# 0     False  A Figure Bowing before a Seated Old Man with h...

# %%
'''

A set of functions to read in JSON-files from the recursive directory structure are defined here:

'''

#Define a function to get immediate successor directories:
def get_immediate_subdirectories(a_dir):
    return [name for name in os.listdir(a_dir)
            if os.path.isdir(os.path.join(a_dir, name))]

#Define a function to get JSON files:
def get_json_files(a_dir):
    return [name for name in os.listdir(a_dir) if (os.path.isfile(os.path.join(a_dir, name)) and name.endswith('.json'))]


#Define a function to recursively build a list of JSON files:
def build_dataset(path):
    items = []
    
    #Get files in current folder:
    for jsonfile in get_json_files(path):
        items.append(path + '/'+jsonfile)
    
    #Get files in subfolders:
    for subdir in get_immediate_subdirectories(path):
        items.extend(build_dataset( path + '/'+subdir))
        
    return items
        

print len(build_dataset("collection/artworks/a/000"))
# Out:
# 99

# %%
#Put everything - and i do mean everything - into an array for easy sampling:
data = build_dataset("collection/artworks")

# %%
#We don't want to test on the entire dataset, but the files are NOT independent of the folder structure:
jsonpaths = random.sample(data, 500)

# %%
df = pd.DataFrame({})


for path in jsonpaths:
    df = df.append(getDataframe(JSONload(path), ['title','id', 'thumbnailUrl', 'acquisitionYear', 'dateText'], is_artist='Turner'), ignore_index = True)

df.head()
# Out:
#   acquisitionYear   dateText     id is_Turner  \
# 0            1978       1971  12829     False
# 1            1856       1798  28876      True
# 2            1856  c.1815–17  38055      True
# 3            1856       1801  32478      True
# 4            2002       1961  66590     False
#
#                                         thumbnailUrl  \
# 0  http://www.tate.org.uk/art/images/work/P/P01/P...
# 1  http://www.tate.org.uk/art/images/work/D/D01/D...
# 2  http://www.tate.org.uk/art/images/work/D/D10/D...
# 3  http://www.tate.org.uk/art/images/work/D/D05/D...
# 4  http://www.tate.org.uk/art/images/work/P/P11/P...
#
#                                        title
# 0                           View of the Emme
# 1     View of Malmesbury from the South West
# 2                                River Scene
# 3  Helmsley Castle Seen across the River Rye
# 4                               The Offering

# %%
#Define a function to map a dateText to a date:
def mapDate(text):
    ns = re.findall(r'\b\d+\b', text)
    
    #If there is no year return NaN:
    if len(ns)==0:
        return np.NaN
    
    #If there is a single year return that:
    elif len(ns)==1:
        return int(ns[0])
    
    #If a range of years has been given, find the average:
    #Note that if some moron wrote 1899-01, we interpret it as 1899-1801, not 1901
    else:
        chars_needed = len(ns[0])-len(ns[1])
        ns[1] = int(ns[0][:chars_needed] + ns[1])
        ns[0] = int(ns[0])
    
        return (ns[0]+ns[1])/2
    
#Map all dateTexts to dates:
df['date_painted'] = df['dateText'].map(lambda x: mapDate(x))
df = df.drop('dateText',1)

#Drop the rows with no thumbnail or no year:
df = df[df['thumbnailUrl'] != 'None']
df = df[np.isfinite(df['date_painted'])]

df = df.reset_index(drop=True)

#Ensure that everything went okay:
df.head()
# Out:
#   acquisitionYear     id is_Turner  \
# 0            1978  12829     False
# 1            1856  28876      True
# 2            1856  38055      True
# 3            1856  32478      True
# 4            2002  66590     False
#
#                                         thumbnailUrl  \
# 0  http://www.tate.org.uk/art/images/work/P/P01/P...
# 1  http://www.tate.org.uk/art/images/work/D/D01/D...
# 2  http://www.tate.org.uk/art/images/work/D/D10/D...
# 3  http://www.tate.org.uk/art/images/work/D/D05/D...
# 4  http://www.tate.org.uk/art/images/work/P/P11/P...
#
#                                        title  date_painted
# 0                           View of the Emme          1971
# 1     View of Malmesbury from the South West          1798
# 2                                River Scene          1816
# 3  Helmsley Castle Seen across the River Rye          1801
# 4                               The Offering          1961

# %%
#Define a function to get a picture from an url:
def get_image(url):
    img = io.imread(url, as_grey = False)
    if not len(img.shape)==3:
        return color.gray2rgb(img)
    return img

#Define an hsv-histogram function:
def hsv_histogram(image_rgb, b, w=[1,1,1]):
    hsv_img = color.rgb2hsv(image_rgb)
    h_histogram = np.histogram(hsv_img[:,:,0], bins=[x/float(b) for x in range(0,b+1)])[0]    
    s_histogram = np.histogram(hsv_img[:,:,1], bins=[x/float(b) for x in range(0,b+1)])[0]
    v_histogram = np.histogram(hsv_img[:,:,2], bins=[x/float(b) for x in range(0,b+1)])[0]
    
    return np.concatenate((h_histogram*w[0], s_histogram*w[1], v_histogram*w[2]))

def rgb_histogram(image_rgb, b, w=[1,1,1]):
    image_rgb = image_rgb/255.0
    
    r_histogram = np.histogram(image_rgb[:,:,0], bins=[x/float(b) for x in range(0,b+1)])[0]    
    g_histogram = np.histogram(image_rgb[:,:,1], bins=[x/float(b) for x in range(0,b+1)])[0]
    b_histogram = np.histogram(image_rgb[:,:,2], bins=[x/float(b) for x in range(0,b+1)])[0]
    
    return np.concatenate((r_histogram*w[0], g_histogram*w[1], b_histogram*w[2]))


img = get_image(df.ix[0, 'thumbnailUrl'])

print rgb_histogram(img, 3)

imshow(img)
# Out:
# [    6 21944 24898   793 28528 17527   867 32715 13266]

# %%
def mapThumbnail(url):
    return hsv_histogram(get_image(url), 3)

df['hsv_buckets'] = df['thumbnailUrl'].map(lambda x: mapThumbnail(x))

# %%
df.head()
# Out:
#   acquisitionYear     id is_Turner  \
# 0            1978  12829     False
# 1            1856  28876      True
# 2            1856  38055      True
# 3            1856  32478      True
# 4            2002  66590     False
#
#                                         thumbnailUrl  \
# 0  http://www.tate.org.uk/art/images/work/P/P01/P...
# 1  http://www.tate.org.uk/art/images/work/D/D01/D...
# 2  http://www.tate.org.uk/art/images/work/D/D10/D...
# 3  http://www.tate.org.uk/art/images/work/D/D05/D...
# 4  http://www.tate.org.uk/art/images/work/P/P11/P...
#
#                                        title  date_painted  \
# 0                           View of the Emme          1971
# 1     View of Malmesbury from the South West          1798
# 2                                River Scene          1816
# 3  Helmsley Castle Seen across the River Rye          1801
# 4                               The Offering          1961
#
#                                          hsv_buckets
# 0  [41542, 2799, 2507, 39961, 6859, 28, 6, 20926,...
# 1  [47194, 6114, 452, 50594, 2629, 537, 13467, 13...
# 2  [35512, 15184, 760, 28358, 22147, 951, 19434, ...
# 3  [31995, 11628, 1177, 42671, 1796, 333, 16008, ...
# 4  [26191, 10112, 10289, 46590, 2, 0, 13750, 5395...

# %%
df.date_painted.value_counts().sort_index().plot()

# %%
df[df['is_Turner']!=True].date_painted.value_counts().sort_index().plot()

# %%
df2= df.groupby(['date_painted', 'is_Turner']).date_painted.count()
df2.head(15)
# Out:
# date_painted  is_Turner
# 1750          False        1
# 1767          False        1
# 1775          False        1
# 1782          False        1
# 1790          False        1
# 1791          True         1
# 1793          False        2
# 1795          True         1
# 1796          True         2
# 1797          True         2
# 1798          True         3
# 1799          True         1
# 1800          True         1
# 1801          True         8
# 1802          True         4
# Name: date_painted, dtype: int64

# %%
df2 = df2.unstack('is_Turner')
decades = (df2.index/10)*10
df2.groupby(decades).mean().plot()

# %%
import matplotlib.pyplot as plt

comb = df['hsv_buckets'].mean()
noturn = df[df['is_Turner']==False]['hsv_buckets'].mean()
turn = df[df['is_Turner']==True]['hsv_buckets'].mean()

ax = plt.subplot()
ax.bar([i-0.2 for i in range(1,10)], comb, width=0.2,color='red')
ax.bar(range(1,10), noturn, width=0.2, color='green')
ax.bar([i+0.2 for i in range(1,10)], turn, width=0.2, color='blue')
plt.show()

# %%
df['rgb_wide_buckets'] = df['thumbnailUrl'].map(lambda x: rgb_histogram(get_image(x), 5))

# %%
comb = df['rgb_wide_buckets'].mean()
noturn = df[df['is_Turner']==False]['rgb_wide_buckets'].mean()
turn = df[df['is_Turner']==True]['rgb_wide_buckets'].mean()

print comb

fig = plt.figure(figsize=(12,6))
ax = plt.subplot()
ax.bar([i-0.2 for i in range(1,16)], comb, width=0.2,color='red')
ax.bar(range(1,16), noturn, width=0.2, color='green')
ax.bar([i+0.2 for i in range(1,16)], turn, width=0.2, color='blue')
plt.show()
# Out:
# [  7669.90526316   3878.77894737   5050.24210526   6819.99736842
#   23715.39210526   8144.17105263   4533.           5057.40526316
#    8098.65526316  21301.08421053   8996.27894737   5124.36052632
#    5843.97631579  11802.91578947  15366.78421053]

# %%
df['wide_hsv_buckets'] = df['thumbnailUrl'].map(lambda x: hsv_histogram(get_image(x), 5))

# %%
comb = df['wide_hsv_buckets'].mean()
noturn = df[df['is_Turner']==False]['wide_hsv_buckets'].mean()
turn = df[df['is_Turner']==True]['wide_hsv_buckets'].mean()

fig = plt.figure(figsize=(12,6))
ax = plt.subplot()
ax.bar([i-0.2 for i in range(1,16)], comb, width=0.2,color='red')
ax.bar(range(1,16), noturn, width=0.2, color='green')
ax.bar([i+0.2 for i in range(1,16)], turn, width=0.2, color='blue')
plt.show()

# %%
df3 = df.groupby(['date_painted'])[['date_painted','rgb_wide_buckets']]

df4 = df3.apply(lambda x: x.rgb_wide_buckets.mean())

df4.to_dict()
# Out:
# {1750.0: array([ 17206.,  10459.,  10053.,   2958.,    284.,  17206.,  10459.,
#          10053.,   2958.,    284.,  17206.,  10459.,  10053.,   2958.,
#            284.]),
#  1767.0: array([  2240.,   9703.,  18021.,  21568.,   1716.,   3478.,  14084.,
#          12325.,  23325.,     36.,  10380.,  14165.,   4517.,  24103.,
#             83.]),
#  1775.0: array([    87.,   4228.,   4230.,  10690.,  27613.,    388.,   5330.,
#           4345.,  20256.,  16529.,   1638.,   6114.,   7111.,  28017.,
#           3968.]),
#  1782.0: array([ 14113.,  17272.,   4107.,   3349.,   1863.,  24468.,   7882.,
#           4046.,   3098.,   1210.,  28250.,   4631.,   3683.,   3499.,
#            641.]),
#  1790.0: array([  2502.,  11052.,  13103.,  20703.,      0.,   2627.,  10380.,
#          26198.,   8155.,      0.,   4769.,  12661.,  29930.,      0.,
#              0.]),
#  1791.0: array([  8549.,   1764.,   3810.,  15090.,  19683.,   8711.,   1759.,
#           4969.,  18062.,  15395.,   8698.,   1820.,   8175.,  23981.,
#           6222.]),
#  1793.0: array([  3023. ,    423. ,   2052.5,  22612. ,  15665.5,   3085. ,
#            615.5,   3259.5,  36510. ,    306. ,   3251.5,   1586. ,
#          10687. ,  28251.5,      0. ]),
#  1795.0: array([  9465.,   2308.,   5870.,   8174.,  26919.,   9714.,   2807.,
#           6320.,   9985.,  23910.,  10332.,   5245.,   8103.,  10791.,
#          18265.]),
#  1796.0: array([ 10016.5,   1227.5,    835.5,   2129. ,  37247.5,  10329. ,
#           1229. ,    741. ,   3260.5,  35896.5,  10466.5,   1426. ,
#           1491. ,   6955. ,  31117.5]),
#  1797.0: array([  9387. ,   1061.5,    670.5,   1521.5,  39455.5,   9809.5,
#            840.5,    863.5,   2155. ,  38427.5,  10197.5,    892. ,
#           1394. ,   8752. ,  30860.5]),
#  1798.0: array([  8897.66666667,   1893.66666667,   2801.33333333,   3465.33333333,
#          30558.        ,   9208.        ,   2701.        ,   3327.66666667,
#           7570.33333333,  24809.        ,  10421.66666667,   3592.33333333,
#           4083.        ,  22484.66666667,   7034.33333333]),
#  1799.0: array([ 10286.,    517.,    589.,   3282.,  33966.,  10514.,    373.,
#           1367.,   5247.,  31139.,  10645.,    975.,   2393.,  24934.,
#           9693.]),
#  1800.0: array([ 10666.,   2870.,  13833.,  18455.,      0.,  11551.,   1750.,
#           5793.,  26730.,      0.,  11878.,   1861.,   6464.,  25621.,
#              0.]),
#  1801.0: array([  8953.875,    732.625,   1572.125,   6388.75 ,  25840.625,
#           9267.75 ,    622.5  ,   2088.25 ,   7185.5  ,  24324.   ,
#           9409.125,    952.75 ,   5219.25 ,  12519.125,  15387.75 ]),
#  1802.0: array([  5576.5 ,   1901.5 ,  15487.5 ,  16461.  ,   9597.5 ,   5719.  ,
#           2276.25,  15047.25,  16743.  ,   9238.5 ,   5886.75,   9528.5 ,
#          12973.5 ,  11862.  ,   8773.25]),
#  1803.0: array([ 14683.,    437.,   1508.,   2849.,  27627.,  14708.,    628.,
#           1862.,   3633.,  26273.,  14835.,   1405.,   1906.,  11534.,
#          17424.]),
#  1804.0: array([  5626.5,    279.5,    529.5,   1921.5,  44507. ,   5781. ,
#            243.5,   1008.5,  10106.5,  35724.5,   5869. ,    868.5,
#           4986.5,  12696. ,  28444. ]),
#  1805.0: array([  7089. ,    965.2,    889.6,   4070.2,  32349.2,   7189.8,
#           1007.6,   1400.8,   9434. ,  26331. ,   7478. ,   1153. ,
#           4692.2,   9876.8,  22163.2]),
#  1806.0: array([  3401.,    461.,   5897.,  24289.,      0.,   3419.,    484.,
#          14295.,  15850.,      0.,   3412.,    725.,  29848.,     63.,
#              0.]),
#  1807.0: array([  7633.25,   1277.25,    694.25,   1503.5 ,  30107.75,   8197.25,
#           1114.25,    626.75,   1720.25,  29557.5 ,   8806.5 ,    737.25,
#           1195.75,   3351.75,  27124.75]),
#  1808.0: array([  0.00000000e+00,   3.50330000e+04,   1.52020000e+04,
#           2.73200000e+03,   7.93000000e+02,   3.20000000e+01,
#           4.04840000e+04,   1.11470000e+04,   1.54800000e+03,
#           5.49000000e+02,   2.63500000e+03,   4.76060000e+04,
#           2.64500000e+03,   8.52000000e+02,   2.20000000e+01]),
#  1809.0: array([ 12483.,   2228.,   1644.,   5608.,  29237.,  14295.,    612.,
#           3494.,   4941.,  27858.,  14497.,   1306.,   5099.,   7689.,
#          22609.]),
#  1810.0: array([  9306. ,   1031. ,   1602.5,   3775.5,  33949. ,   9700.5,
#            908.5,   2720.5,   4069.5,  32265. ,   9950. ,   1879. ,
#           2950.5,  12444. ,  22440.5]),
#  1811.0: array([  5896.5 ,    921.  ,   3310.5 ,   7597.5 ,  29122.5 ,   6090.  ,
#           1367.5 ,   4467.25,   9191.75,  25731.5 ,   6443.5 ,   3004.25,
#           6708.5 ,  14707.5 ,  15984.25]),
#  1812.0: array([  1273.5,  11602. ,   9866.5,  11012.5,  11557.5,   1924. ,
#          13957.5,  12819.5,   7038. ,   9573. ,   3887.5,  15677.5,
#          14073.5,   3648.5,   8025. ]),
#  1813.0: array([  7366.5,    454.5,   1105. ,  11612. ,  23622. ,   7507. ,
#            422. ,   2678.5,  15344.5,  18208. ,   7636. ,   1799.5,
#           7172. ,  26665.5,    887. ]),
#  1814.0: array([  9904.25,    750.75,   1769.25,   5572.5 ,  25395.25,  10155.  ,
#            755.  ,   2373.5 ,   9097.5 ,  21011.  ,  10317.25,   1365.75,
#           3233.  ,  17453.75,  11022.25]),
#  1816.0: array([ 14053.66666667,   1211.33333333,   4180.33333333,   7437.33333333,
#          20306.66666667,  14486.66666667,   1532.33333333,   8881.        ,
#           2765.        ,  19524.33333333,  14974.        ,   4970.        ,
#           6415.66666667,   5943.33333333,  14886.33333333]),
#  1817.0: array([  7615.875,   1354.125,    637.   ,   4237.5  ,  34763.5  ,
#           8525.   ,    637.   ,   1150.25 ,   8115.   ,  30180.75 ,
#           8761.75 ,   1022.875,   5897.   ,   8429.625,  24496.75 ]),
#  1818.0: array([ 10731.,   1744.,    558.,   3516.,  36187.,  12248.,    414.,
#            960.,   4034.,  35080.,  12333.,    437.,   1815.,   6812.,
#          31339.]),
#  1819.0: array([ 11056.66666667,   1143.125     ,   2319.79166667,   2658.375     ,
#          27334.04166667,  11386.41666667,   1537.        ,   1972.        ,
#           3714.79166667,  25901.79166667,  11827.58333333,   2472.125     ,
#           1586.29166667,   8556.20833333,  20069.79166667]),
#  1820.0: array([ 13031.66666667,   1239.        ,    896.        ,   2651.33333333,
#          30651.33333333,  13567.33333333,    964.66666667,   1013.        ,
#           3336.        ,  29588.33333333,  13829.        ,   1083.66666667,
#           1806.        ,   6392.        ,  25358.66666667]),
#  1821.0: array([  6.00000000e+00,   8.32300000e+03,   1.44440000e+04,
#           8.84700000e+03,   1.95800000e+04,   3.30000000e+01,
#           9.58400000e+03,   1.51080000e+04,   9.40000000e+03,
#           1.70750000e+04,   1.66000000e+02,   1.16200000e+04,
#           1.51030000e+04,   1.23360000e+04,   1.19750000e+04]),
#  1822.0: array([  5369.5,   5294.5,   4417.5,   6286.5,  24072. ,   5543.5,
#           5789. ,   4458. ,   9273. ,  20376.5,   6257. ,   6285.5,
#           4777.5,  14480.5,  13639.5]),
#  1823.0: array([ 15857.5,   1243.5,    354.5,   1426. ,  33214.5,  16562. ,
#            758. ,    397.5,   3720. ,  30658.5,  17017.5,    396. ,
#            928.5,  11750.5,  22003.5]),
#  1824.0: array([  8927.18181818,   1989.18181818,   3412.18181818,   7163.63636364,
#          27147.81818182,   9382.72727273,   2169.36363636,   4546.54545455,
#           8036.09090909,  24505.27272727,   9917.36363636,   2864.27272727,
#           6119.27272727,   8241.        ,  21498.09090909]),
#  1825.0: array([  6276.875,   1511.875,   3137.375,   6456.5  ,  27833.375,
#           6592.75 ,   1408.   ,   3901.75 ,  10477.625,  22835.875,
#           7239.875,   3510.75 ,   3996.25 ,  15183.25 ,  15285.875]),
#  1826.0: array([  2102.33333333,   9719.66666667,   5302.66666667,  16217.66666667,
#          13932.33333333,   2547.        ,  11939.33333333,   3293.66666667,
#          15660.        ,  13834.66666667,  10858.66666667,   5228.33333333,
#           2284.33333333,  28819.        ,     84.33333333]),
#  1827.0: array([  5392.42857143,   5413.14285714,  12799.42857143,   9234.57142857,
#          10826.71428571,   6941.        ,   5961.85714286,  10663.57142857,
#          11350.14285714,   8749.71428571,  10800.85714286,   4314.85714286,
#          11355.14285714,   9611.85714286,   7583.57142857]),
#  1828.0: array([  9338.6       ,    459.53333333,    712.2       ,   3308.6       ,
#          33592.26666667,   9392.8       ,    503.06666667,   1252.        ,
#           6317.86666667,  29945.46666667,   9592.86666667,    789.33333333,
#           2080.2       ,  15799.73333333,  19149.06666667]),
#  1829.0: array([ 10084.5,    884.5,    454.5,   4439. ,  30985.5,   9779.5,
#           1243.5,    820. ,   4914.5,  30090.5,  10675.5,    731. ,
#           3042. ,  19113.5,  13286. ]),
#  1830.0: array([  5682.5  ,   5816.25 ,  10821.5  ,   6241.125,  17774.625,
#           6974.625,   7191.75 ,   8474.5  ,   6978.625,  16716.5  ,
#           9130.125,   7768.25 ,   6283.   ,  14512.5  ,   8642.125]),
#  1831.0: array([  8196.25      ,   1010.91666667,   2571.66666667,   4261.66666667,
#          29868.83333333,   8701.58333333,    820.08333333,   2191.33333333,
#           7145.91666667,  27050.41666667,   8910.83333333,   1632.16666667,
#           3023.        ,  17521.83333333,  14821.5       ]),
#  1832.0: array([  7034.75,   1388.  ,   5751.25,   8639.25,  28130.75,   7074.  ,
#           1018.5 ,   6080.  ,   9942.5 ,  26829.  ,   7230.75,   1670.  ,
#           8560.  ,  10412.5 ,  23070.75]),
#  1833.0: array([  8582.36363636,   1188.27272727,   1578.18181818,   2578.36363636,
#          29662.63636364,   8738.81818182,   1294.        ,   1678.63636364,
#           3084.54545455,  28793.81818182,   8961.81818182,   1583.54545455,
#           2190.72727273,   9505.54545455,  21348.18181818]),
#  1834.0: array([  6778.        ,    746.28571429,   1484.        ,   6314.28571429,
#          30135.71428571,   6881.42857143,    917.        ,   1850.42857143,
#           7075.14285714,  28734.28571429,   7026.71428571,   1492.57142857,
#           5754.57142857,  14969.71428571,  16214.71428571]),
#  1835.0: array([  5954.94444444,   2324.44444444,   2351.        ,   7251.22222222,
#          27743.27777778,   6323.44444444,   2467.61111111,   2619.38888889,
#           9075.72222222,  25138.72222222,   6728.83333333,   2790.66666667,
#           3874.05555556,  21907.05555556,  10324.27777778]),
#  1836.0: array([  8261.83333333,   2799.16666667,   4611.5       ,   7906.16666667,
#          22330.66666667,   8581.16666667,   3287.5       ,   6065.33333333,
#           7398.        ,  20577.33333333,   9046.33333333,   3971.        ,
#           7823.5       ,  10901.16666667,  14167.33333333]),
#  1838.0: array([  3.00000000e+00,   6.24000000e+02,   5.11100000e+03,
#           1.33310000e+04,   1.29310000e+04,   2.80000000e+01,
#           1.90700000e+03,   9.23300000e+03,   1.50620000e+04,
#           5.77000000e+03,   6.62000000e+02,   5.11500000e+03,
#           1.15100000e+04,   1.45210000e+04,   1.92000000e+02]),
#  1839.0: array([  8117.11111111,    708.66666667,    425.88888889,   2267.88888889,
#          30891.11111111,   8360.        ,    581.66666667,    591.55555556,
#           4908.66666667,  27968.77777778,   8602.22222222,    601.11111111,
#           1466.11111111,  18072.44444444,  13668.77777778]),
#  1840.0: array([  8520.85714286,    464.42857143,    719.85714286,   1735.71428571,
#          34895.14285714,   8618.71428571,    481.85714286,   1041.42857143,
#           2788.57142857,  33405.42857143,   8722.57142857,    809.28571429,
#           1425.71428571,  19080.57142857,  16297.85714286]),
#  1841.0: array([  8857.33333333,    847.33333333,    506.33333333,   1396.        ,
#          31145.        ,   8929.        ,    855.33333333,    475.        ,
#           1349.        ,  31143.66666667,   9194.66666667,    696.33333333,
#            739.66666667,   1863.        ,  30258.33333333]),
#  1843.0: array([ 22944. ,   3359. ,   1151. ,   1611. ,  13687. ,  25702. ,
#           2994. ,    647. ,    361. ,  13048. ,  27893.5,   1358.5,
#            145.5,   2800.5,  10554. ]),
#  1844.0: array([  8195.66666667,    280.66666667,    205.33333333,   1055.33333333,
#          35063.        ,   8210.33333333,    279.66666667,    249.33333333,
#           1319.        ,  34741.66666667,   8237.        ,    278.66666667,
#            378.66666667,   5042.66666667,  30863.        ]),
#  1845.0: array([ 13860.66666667,   1637.33333333,    739.66666667,   2817.33333333,
#          32145.        ,  15164.33333333,    567.66666667,    929.33333333,
#           3131.        ,  31407.66666667,  15307.        ,    675.33333333,
#           1457.33333333,   5875.33333333,  27885.        ]),
#  1856.0: array([  1965.5,  14300. ,   7795. ,  13499. ,  13896.5,   4506.5,
#          12684.5,   9688.5,  23634.5,    942. ,  11931. ,  10555. ,
#          19005. ,   9910.5,     54.5]),
#  1858.0: array([     0.,   7438.,  13012.,  11160.,  21894.,    470.,  19508.,
#           9462.,  10393.,  13671.,   3353.,  24137.,   2671.,   6587.,
#          16756.]),
#  1860.0: array([  3252.5,   5796.5,   4672.5,  15461. ,   8577.5,   3618. ,
#           5933. ,   4977.5,  17648. ,   5583.5,   4270.5,   6056. ,
#           6135. ,  18157.5,   3141. ]),
#  1861.0: array([  0.00000000e+00,   1.14800000e+03,   1.11640000e+04,
#           1.78280000e+04,   2.74600000e+04,   0.00000000e+00,
#           1.76000000e+03,   1.24680000e+04,   2.76320000e+04,
#           1.57400000e+04,   1.00000000e+00,   5.10900000e+03,
#           1.64540000e+04,   3.60360000e+04,   0.00000000e+00]),
#  1864.0: array([  8.28000000e+02,   1.28220000e+04,   2.00570000e+04,
#           1.35090000e+04,   1.44000000e+02,   2.83800000e+03,
#           2.05140000e+04,   1.18180000e+04,   1.21810000e+04,
#           9.00000000e+00,   1.45030000e+04,   1.32740000e+04,
#           6.38600000e+03,   1.31970000e+04,   0.00000000e+00]),
#  1887.0: array([  0.00000000e+00,   0.00000000e+00,   1.50000000e+01,
#           4.35000000e+03,   3.32670000e+04,   0.00000000e+00,
#           0.00000000e+00,   2.40000000e+01,   5.48600000e+03,
#           3.21220000e+04,   0.00000000e+00,   0.00000000e+00,
#           1.04000000e+02,   9.82200000e+03,   2.77060000e+04]),
#  1899.0: array([  1.47900000e+04,   1.23600000e+03,   1.63480000e+04,
#           2.69800000e+03,   0.00000000e+00,   1.01260000e+04,
#           5.65800000e+03,   9.95500000e+03,   9.33200000e+03,
#           1.00000000e+00,   3.15100000e+03,   1.17470000e+04,
#           2.84100000e+03,   1.73330000e+04,   0.00000000e+00]),
#  1911.0: array([  6800.,  13327.,   7625.,   5349.,  29619.,  10445.,  11633.,
#           6873.,   6553.,  27216.,  12780.,  10905.,   6393.,  30958.,
#           1684.]),
#  1913.0: array([  1.02760000e+04,   1.32490000e+04,   1.01145000e+04,
#           1.24915000e+04,   3.91700000e+03,   8.58700000e+03,
#           1.63865000e+04,   1.16620000e+04,   1.27955000e+04,
#           6.17000000e+02,   9.94400000e+03,   2.02585000e+04,
#           1.57535000e+04,   4.09100000e+03,   1.00000000e+00]),
#  1916.0: array([  4.00000000e+00,   7.21000000e+02,   4.05800000e+03,
#           1.06350000e+04,   2.98940000e+04,   1.06000000e+02,
#           1.79500000e+03,   5.79200000e+03,   1.35990000e+04,
#           2.40200000e+04,   6.76000000e+02,   3.88700000e+03,
#           1.02250000e+04,   3.04910000e+04,   3.30000000e+01]),
#  1917.0: array([ 13908. ,  20648.5,   2648. ,   5416. ,   3587.5,  15664.5,
#          19765. ,   2581. ,   4874. ,   3323.5,  16954.5,  10312.5,
#          13379.5,   2411. ,   3150.5]),
#  1922.0: array([    90.,  28057.,  11346.,   9807.,   1900.,    110.,  29318.,
#          13667.,   7932.,    173.,    615.,  24149.,  24922.,   1514.,
#              0.]),
#  1926.0: array([  1339.5,   6956. ,  16568.5,   7140. ,  15228. ,  10174.5,
#          12739.5,   4921. ,   6633. ,  12764. ,  13945. ,  10365.5,
#           6570. ,  16295.5,     56. ]),
#  1929.0: array([  1258. ,  12966. ,  19862. ,   9080.5,   1505.5,   3776.5,
#          20544.5,  12315.5,   6733. ,   1302.5,  10170.5,  20039. ,
#           8404.5,   5055.5,   1002.5]),
#  1930.0: array([  4793.,   8625.,   9953.,  14435.,  16466.,   7552.,   9498.,
#           8576.,  15236.,  13410.,  11501.,  10398.,   3851.,   6416.,
#          22106.]),
#  1933.0: array([  1.78400000e+03,   2.18380000e+04,   1.66820000e+04,
#           3.47100000e+03,   1.00000000e+00,   2.88200000e+03,
#           2.89220000e+04,   1.10360000e+04,   9.36000000e+02,
#           0.00000000e+00,   8.79300000e+03,   2.85200000e+04,
#           6.18600000e+03,   2.77000000e+02,   0.00000000e+00]),
#  1935.0: array([ 18293.33333333,  13229.66666667,  10853.33333333,   7793.33333333,
#           1457.        ,  16501.66666667,  15261.        ,  10755.        ,
#           8598.        ,    511.        ,  19892.33333333,  15428.33333333,
#           9855.66666667,   6419.        ,     31.33333333]),
#  1937.0: array([  2802.,   6130.,   4115.,   2645.,  47540.,   3652.,   6022.,
#           3873.,   2667.,  47018.,   4752.,   6279.,   3575.,  16229.,
#          32397.]),
#  1950.0: array([  0.00000000e+00,   0.00000000e+00,   1.70000000e+01,
#           2.22670000e+04,   2.58440000e+04,   0.00000000e+00,
#           0.00000000e+00,   1.36000000e+02,   4.55020000e+04,
#           2.49000000e+03,   0.00000000e+00,   0.00000000e+00,
#           7.25000000e+02,   4.57170000e+04,   1.68600000e+03]),
#  1951.0: array([  1298.        ,   6499.33333333,  14076.        ,  12876.33333333,
#          20119.66666667,    390.66666667,   5900.        ,  13329.33333333,
#          14325.66666667,  20923.66666667,    331.        ,   5153.        ,
#           9918.        ,  17669.33333333,  21798.        ]),
#  1952.0: array([ 20350. ,   8367. ,  13047.5,   7679. ,   2652.5,   6410. ,
#          21543.5,  13139. ,   7467. ,   3536.5,   5846.5,   7630. ,
#          24185. ,   9594.5,   4840. ]),
#  1953.0: array([     0.,     45.,   4950.,  16885.,   4488.,    135.,  14347.,
#           2875.,   5328.,   3683.,   8843.,   8327.,   5287.,   1816.,
#           2095.]),
#  1954.0: array([  2319.,   1705.,    327.,   2127.,  39090.,   3181.,    896.,
#            548.,   3606.,  37337.,   3605.,    568.,   1005.,   9807.,
#          30583.]),
#  1957.0: array([   369.,   1071.,   3888.,  22566.,  23306.,     88.,   1200.,
#           5931.,  39131.,   4850.,   2383.,   3503.,   6536.,  38465.,
#            313.]),
#  1958.0: array([  1.50000000e+01,   8.45000000e+02,   5.10200000e+03,
#           4.10000000e+04,   5.00600000e+03,   1.58600000e+03,
#           3.46100000e+03,   3.99110000e+04,   3.78400000e+03,
#           3.22600000e+03,   3.46800000e+04,   1.06270000e+04,
#           1.96800000e+03,   3.28800000e+03,   1.40500000e+03]),
#  1959.0: array([  4143.33333333,    641.66666667,   1144.33333333,   3485.        ,
#          29497.66666667,   4204.        ,    712.33333333,   1144.66666667,
#           5345.66666667,  27505.33333333,   4316.        ,    818.66666667,
#           1169.        ,   8880.66666667,  23727.66666667]),
#  1961.0: array([  5261. ,   5727. ,   6991.5,  10567. ,  13309.5,   5341.5,
#           5651.5,   6990.5,  10560.5,  13312. ,   5073.5,   5898.5,
#           7003. ,  10560.5,  13320.5]),
#  1962.0: array([  8.78000000e+03,   1.29750000e+04,   1.92980000e+04,
#           1.61000000e+02,   2.00000000e+00,   1.24210000e+04,
#           1.71480000e+04,   1.15130000e+04,   1.32000000e+02,
#           2.00000000e+00,   1.64020000e+04,   1.50070000e+04,
#           9.56100000e+03,   2.39000000e+02,   7.00000000e+00]),
#  1963.0: array([ 14985.66666667,   4629.33333333,   2320.33333333,   5364.        ,
#          20572.66666667,  16107.33333333,   3948.66666667,   2827.66666667,
#          12573.33333333,  12415.        ,  17239.        ,   4397.66666667,
#          10512.33333333,  14208.33333333,   1514.66666667]),
#  1966.0: array([ 16966. ,   9183. ,   7525. ,  12028.5,   6777.5,  22375.5,
#           8807.5,   5769.5,  10188. ,   5339.5,  24272.5,   9374.5,
#           5440.5,   8278.5,   5114. ]),
#  1967.0: array([  1636.5,   8847.5,  20349. ,  16353. ,   7214. ,   3321.5,
#          32276. ,   6718.5,   5523. ,   6561. ,   3188.5,   4935.5,
#          34310. ,   7682.5,   4283.5]),
#  1968.0: array([  3489.25,   4284.  ,  16745.5 ,   4400.5 ,  19272.75,  17309.75,
#           4381.5 ,   6343.5 ,   2441.5 ,  17715.75,  16888.25,   6559.5 ,
#           5783.  ,   1712.25,  17249.  ]),
#  1969.0: array([  3118.2,   5805.4,   5493.8,   7623. ,  20814. ,   2847.2,
#           7449.2,   6501.6,   8572.2,  17484.2,   4512. ,   8856.6,
#           6293. ,  16401.4,   6791.4]),
#  1970.0: array([   649.16666667,   3890.33333333,   5641.        ,   5734.83333333,
#          32255.33333333,   1178.5       ,   7081.16666667,   9029.5       ,
#           4068.5       ,  26813.        ,   1608.16666667,  10482.16666667,
#           7903.        ,   5076.83333333,  23100.5       ]),
#  1971.0: array([  1893.4,   9600.4,   3530.4,  10262. ,  27808.2,   1858.2,
#           3102.2,  10797. ,  19359.2,  17977.8,   9728.6,   3394.2,
#          16278.4,   6557.8,  17135.4]),
#  1972.0: array([ 20562.44444444,   7417.11111111,   6587.44444444,   6830.66666667,
#          12021.        ,  19717.22222222,   9170.33333333,   5703.11111111,
#           9607.55555556,   9220.44444444,  19516.33333333,  10379.66666667,
#           5958.        ,   7133.44444444,  10431.22222222]),
#  1973.0: array([ 15225. ,   4489.5,  28673. ,   1293. ,   4719.5,  10747. ,
#           7297. ,  29592.5,   2390. ,   4373.5,   6530. ,  34199. ,
#           6605.5,   3788.5,   3277. ]),
#  1974.0: array([   565. ,    835.5,    817.5,   4072. ,  39918. ,    397. ,
#           1403.5,   1291.5,   7424. ,  35692. ,   1251. ,   2992.5,
#           1414.5,  10867. ,  29683. ]),
#  1975.0: array([  1410. ,   6967.5,  17436.5,  13374.5,   8811.5,   1285. ,
#           6554.5,  17006. ,  10583.5,  12571. ,   1842. ,   8065. ,
#          16044.5,   9154.5,  12894. ]),
#  1976.0: array([   964.5 ,   5477.5 ,   4302.75,  11190.75,  14928.5 ,    675.5 ,
#           4405.75,   4122.5 ,  12434.5 ,  15225.75,   1020.  ,   6909.75,
#           5488.25,  12814.25,  10631.75]),
#  1977.0: array([  4400. ,   6800. ,   5024. ,  12672. ,  21280. ,   2163. ,
#           7032.5,   4843.5,  14468.5,  21668.5,   3139. ,  10666.5,
#          14279.5,   2278.5,  19812.5]),
#  1978.0: array([  8075.5,   4692. ,  26047.5,   2714. ,   8263. ,  10510.5,
#           8903. ,  16503.5,   5456.5,   8418.5,  12638. ,   3737. ,
#          19700.5,   4261. ,   9455.5]),
#  1979.0: array([   870.,   2299.,   1868.,   2786.,  36465.,    608.,   2799.,
#           3326.,   1434.,  36121.,   1798.,   3404.,   2675.,    462.,
#          35949.]),
#  1980.0: array([   422.75,   5183.5 ,  14626.  ,  17798.75,  18289.  ,    325.  ,
#           6049.5 ,  14406.5 ,  18003.75,  17535.25,   1142.25,  16880.25,
#           4103.5 ,  18075.75,  16118.25]),
#  1981.0: array([  4908.33333333,   6614.66666667,   6732.        ,   8969.33333333,
#          22695.66666667,   3994.        ,   7834.66666667,   5666.66666667,
#           9726.66666667,  22698.        ,   3556.        ,   8991.        ,
#           4992.        ,  10000.        ,  22381.        ]),
#  1982.0: array([  5221.33333333,  11848.        ,   3191.66666667,   5835.66666667,
#          28175.33333333,   6353.66666667,   9167.33333333,   7766.        ,
#           3470.        ,  27515.        ,   6625.33333333,   5798.66666667,
#          11042.        ,   5372.        ,  25434.        ]),
#  1984.0: array([ 17630.5,   5784.5,   7683. ,   6872. ,  10542. ,  21184. ,
#           5908. ,   5487.5,   5450. ,  10482.5,  17478.5,   9434. ,
#           4708.5,   6264. ,  10627. ]),
#  1986.0: array([  1022.33333333,   2025.66666667,   2126.33333333,   2830.33333333,
#          41318.        ,    990.33333333,   1633.        ,   1694.33333333,
#           3685.66666667,  41319.33333333,    939.66666667,   1656.33333333,
#           1407.33333333,   3497.66666667,  41821.66666667]),
#  1987.0: array([ 31147.,    789.,    288.,  26064.,   6480.,  31273.,    691.,
#            297.,  28391.,   4116.,  31399.,    612.,    611.,  28451.,
#           3695.]),
#  1988.0: array([  1559.5,   2554. ,  13595.5,  21322.5,   6792.5,    345. ,
#           9567.5,   8482.5,  20389.5,   7039.5,    105.5,   5276. ,
#          12157.5,  16387.5,  11897.5]),
#  1989.0: array([   746.,   4458.,  19702.,   2545.,  20933.,    788.,   4620.,
#          20875.,   1464.,  20637.,   3809.,   4624.,  13732.,   8490.,
#          17729.]),
#  1990.0: array([ 25788.5,   9979.5,  16072. ,   6323.5,   4684.5,  26060. ,
#           3852.5,  15126.5,  12879. ,   4930. ,  25795. ,   2591. ,
#          10369.5,  13542.5,  10550. ]),
#  1991.0: array([  7140.5,   6024.5,   3413.5,  14530. ,  16763.5,  13584. ,
#          13051. ,   3475.5,   1771.5,  15990. ,   7342.5,  17848.5,
#           5635.5,   1043. ,  16002.5]),
#  1992.0: array([ 13948.66666667,   8507.33333333,   4459.33333333,  11375.66666667,
#          15981.        ,   9088.33333333,  13598.33333333,   4681.33333333,
#          11708.66666667,  15195.33333333,   5297.        ,  17374.33333333,
#           4127.        ,  11779.        ,  15694.66666667]),
#  1994.0: array([ 25710.5,  12155.5,   1812. ,   1321.5,  12376.5,  22942.5,
#          14726.5,   2108. ,   1286. ,  12313. ,  17732.5,  19599.5,
#           2660.5,   1166. ,  12217.5]),
#  1995.0: array([  1594. ,   1944.5,   3328.5,   9630. ,  30223. ,   1806.5,
#           2047.5,   3694.5,  10986. ,  28185.5,   2080.5,   2209. ,
#           4365. ,  13897. ,  24168.5]),
#  1997.0: array([  3451.5 ,  15055.  ,  11728.75,   9981.5 ,   8999.25,   5692.  ,
#          13370.  ,  13146.25,  10994.5 ,   6013.25,   6692.75,  13577.25,
#          16127.75,   8630.5 ,   4187.75]),
#  1998.0: array([  6263.,   2361.,   2006.,   3576.,  31362.,   5974.,   2558.,
#           1808.,   4326.,  30902.,   5637.,   2771.,   2485.,   3351.,
#          31324.]),
#  1999.0: array([  0.00000000e+00,   0.00000000e+00,   1.18200000e+03,
#           4.21100000e+03,   3.96630000e+04,   0.00000000e+00,
#           3.00000000e+00,   4.45500000e+03,   9.42000000e+02,
#           3.96560000e+04,   0.00000000e+00,   1.54500000e+03,
#           3.66200000e+03,   3.56000000e+02,   3.94930000e+04]),
#  2002.0: array([   580.  ,     54.75,    153.5 ,   1005.25,  49214.5 ,    584.25,
#            109.  ,    439.  ,   1561.25,  48314.5 ,    598.25,    203.25,
#            886.  ,   1698.75,  47621.75]),
#  2004.0: array([  7837.,   9043.,  12554.,  13609.,   1501.,   8877.,  12052.,
#          16382.,   6415.,    818.,  12530.,  12231.,  16666.,   2572.,
#            545.]),
#  2007.0: array([  4465. ,   4669.5,   3225.5,  12778. ,  19022. ,   4465. ,
#           4669.5,   3225.5,  12778. ,  19022. ,   4465. ,   4669.5,
#           3225.5,  12778. ,  19022. ]),
#  2010.0: array([  8.25000000e+02,   3.06770000e+04,   1.61890000e+04,
#           1.88600000e+03,   8.70000000e+01,   1.32000000e+03,
#           3.34710000e+04,   1.38050000e+04,   1.05900000e+03,
#           9.00000000e+00,   1.24440000e+04,   3.52590000e+04,
#           1.93400000e+03,   2.70000000e+01,   0.00000000e+00])}

# %% [markdown]
# Part2: Predictive Model (40pts)
# ----
#
# Use your knowledge of the data to build a predictive model. Suggested Python module to use here: `sklearn`.
#
# You can either predict missing values in the data, use the data to predict another data set, or use another data set to predict this data set, or, or, or...
#
# Grading will consider the complexity of the model, its performance, and the difficulty of the prediction task.

# %% [markdown]
# Part3: Visualization (30pts)
# ----
#
# Finally, visualize either the original data, the predictibve model, or both. Grading will take into account how informative and creative the visualization is. When in doubt, an informative visualization is worth more than a creative one!
